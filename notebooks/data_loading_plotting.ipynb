# %%
import sys
sys.path.append('../src')

# %%
from loading import *
from helpers import top_signals
from visualization import *

# %% [markdown]
# ## Loading iEEG and setting the variables

# %%
data_path = "../data/"
patient_data = load_patient_seizures(data_path, 2,all_seizures=False)

# %%
eegs = patient_data['eegs']
ranges = patient_data['ranges']
seizure_start_s = patient_data["infos"]["seizure_start"]
seizure_end_s = patient_data["infos"]["seizure_end"]

# %% [markdown]
# ### Finding best signal to plot

# %%
top5_power_eeg = top_signals(eegs,ranges, top=5)
print(top5_power_eeg)
# Out:
# [48, 49, 56, 57, 20]

# %% [markdown]
# ## Plot examples

# %%
plot_one_signal(eegs[0][0][57] , ranges, 100000, seizure_id=0)
# Out:
# time 144163
# data 1843200
# []

# %%
plot_multiple_signals(eegs[0][0], top5_power_eeg, ranges, 100000, seizure_id=0)
